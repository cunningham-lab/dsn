# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from lib.tf_util.systems import system_from_str
from train_dsn import train_dsn
import seaborn as sns
import pandas as pd
import scipy.stats
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
system_str = 'normal';
D = 2;
T = 1;

TIF_flow_type = 'PlanarFlowLayer';
nlayers = 4;
flow_dict = {'latent_dynamics':None, \
             'TIF_flow_type':TIF_flow_type, \
             'repeats':nlayers, \
             'scale_layer':False};

n = 1000;
k_max = 10;
c_init_order = 0;
lr_order = -3;
random_seed = 0;
min_iters = 1000;
max_iters = 2000;
check_rate = 100;
dir_str = 'test';

# %%
K = 1;

system_class = system_from_str(system_str);
system = system_class(D, T);

np.random.seed(0);
mu = np.zeros((D,));
df_fac = 15;
df = df_fac*D;
Sigma_dist = scipy.stats.invwishart(df=df, scale=df*np.eye(D));
Sigma = Sigma_dist.rvs(1);

behavior = {'mu':mu, 'Sigma':Sigma};

print('mu');
print(mu);
print('Sigma');
print(Sigma[0]);
print(Sigma[1]);
# Out:
# mu
# [0. 0.]
# Sigma
# [ 1.12153224 -0.64198659]
# [-0.64198659  2.074905  ]

# %%
cost, phi, T_x = train_dsn(system, behavior, n, flow_dict, \
                       k_max=k_max, c_init_order=c_init_order, lr_order=lr_order,\
                       random_seed=random_seed, min_iters=min_iters, max_iters=max_iters, \
                       check_rate=check_rate, dir_str=dir_str);
# Out:
# {'mu': array([0., 0.]), 'Sigma': array([[ 1.12153224, -0.64198659],
#        [-0.64198659,  2.074905  ]])}
# 0 <lib.tf_util.flows.PlanarFlowLayer object at 0x12cc31ef0>
# 1 <lib.tf_util.flows.PlanarFlowLayer object at 0x13ee766d8>
# 2 <lib.tf_util.flows.PlanarFlowLayer object at 0x13ee76a58>
# 3 <lib.tf_util.flows.PlanarFlowLayer object at 0x13ee76208>
# 0 PlanarFlow_Layer1
# 1 PlanarFlow_Layer2
# 2 PlanarFlow_Layer3
# 3 PlanarFlow_Layer4
# /Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# training DSN for normal
# AL iteration 1
# resetting optimizer
# Aug Lag it 0
# lambda [0. 0. 0. 0. 0.]
# c 1
# saving model at iter 0
# ******************************************
# it = 100
# H 1.7307906887094127
# R2 0.49155018114044113
# cost -0.9481488245308867
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 200
# H 1.9654032192397912
# R2 0.5474740309781232
# cost -1.5733411502796193
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 300
# H 1.9109190187594085
# R2 0.48568888603599214
# cost -1.6891476180686453
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 400
# H 1.9299651725474525
# R2 0.5142820374381853
# cost -1.7663267771280198
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 500
# H 1.8898275082141909
# R2 0.5045055391925094
# cost -1.7499356716504948
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 600
# H 1.8942412862199798
# R2 0.48304170267758784
# cost -1.7567577810830894
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 700
# H 1.9083704022877104
# R2 0.4861298964268176
# cost -1.7295313356123116
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 800
# H 1.9770216241625231
# R2 0.5053499487260579
# cost -1.8371988419567047
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 900
# H 1.9892561580265185
# R2 0.463854648898288
# cost -1.8510006460183015
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1000
# H 1.935801897608865
# R2 0.499190172565105
# cost -1.7939456179195823
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1100
# H 1.9949068142600852
# R2 0.4982945515641939
# cost -1.8620133595600916
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1200
# H 2.0145158065233075
# R2 0.5179059758353701
# cost -1.8836054160663098
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 1300
# H 1.9541368828587133
# R2 0.5140013991201138
# cost -1.8292620438237999
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1400
# H 1.94852875872517
# R2 0.45187201588347936
# cost -1.7986317313625377
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1500
# H 2.0051916742495397
# R2 0.48446721593880937
# cost -1.863694838490953
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1600
# H 1.9699025528371399
# R2 0.4847601473134001
# cost -1.833056965724839
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1700
# H 1.967624652398893
# R2 0.4581966394620295
# cost -1.8415931545505755
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1800
# H 2.1051851391294965
# R2 0.5024840258678074
# cost -1.9983361566640623
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 1900
# H 2.1020375768562753
# R2 0.4993157677369968
# cost -1.9825375399131013
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2000
# H 1.9288571230434677
# R2 0.48551237038731576
# cost -1.8060770821540233
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/
# AL iteration 2
# resetting optimizer
# Aug Lag it 1
# lambda [ 0.14041758 -0.01090138 -0.33190769 -0.26573681 -0.16513218]
# c 10
# saving model at iter 0
# ******************************************
# it = 2100
# H 2.1586083004849606
# R2 0.4494436219364253
# cost -0.9918731444922823
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2200
# H 2.064383301186287
# R2 0.43095941556681716
# cost -0.5602251345349967
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2300
# H 2.1425662039812523
# R2 0.5307691186409418
# cost -1.0323310204506115
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2400
# H 2.169484363150978
# R2 0.47422046099696125
# cost -1.2609205559640109
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2500
# H 2.2189918722770003
# R2 0.4782110751930023
# cost -1.3555172681958845
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 2600
# H 2.223735346635645
# R2 0.4560997291309655
# cost -1.3674578618650675
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2700
# H 2.2108217785217503
# R2 0.43586328457710577
# cost -1.3312781348249167
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2800
# H 2.287699372242465
# R2 0.41355940569668725
# cost -1.6611060465925598
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 2900
# H 2.33948521211345
# R2 0.4362594750361828
# cost -1.8950719554640514
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 3000
# H 2.3172821833303283
# R2 0.3956237039576952
# cost -1.875691610955753
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 3100
# H 2.4658844527099064
# R2 0.4092998084525641
# cost -2.199390451106199
# saving to results/test//tb/normal_D=2_T=1_flow=4P_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 3200
# H 2.468505720954715
# R2 0.387630675234405
# cost -2.381912926650337
