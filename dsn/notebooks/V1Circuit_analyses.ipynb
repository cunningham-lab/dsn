# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('../');
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from dsn.train_dsn import train_dsn
from dsn.util.systems import V1Circuit
from dsn.util.dsn_util import get_savedir
from dsn.util.plot_util import assess_constraints, plot_opt

# normalizing flow layer architecture
TIF_flow_type = 'PlanarFlowLayer'
# number of layers
nlayers = 10
# add a scaling layer
elem_mult_flow = True
arch_dict = {'D':8, \
             'latent_dynamics':None, \
             'elem_mult_flow':elem_mult_flow, \
             'TIF_flow_type':TIF_flow_type, \
             'repeats':nlayers};
# multivariate normal initialization variance
sigma_init = 1.0
random_seed = 1

# %%
# create an instance of the V1_circuit system class
fixed_params = {'W_EE':1.0, \
                'W_PE':1.0, \
                'W_SE':1.0, \
                'W_VE':1.0, \
                'h_FFE':0.0, \
                'h_FFP':0.0, \
                'h_LATE':0.0, \
                'h_LATP':0.0, \
                'h_LATS':0.0, \
                'h_LATV':0.0, \
                'tau':1.0, \
                'n':2.0, \
                's_0':30};

diff_inds = [0, 1, 2, 3]
c_vals=np.array([0.0])
s_vals=np.array([1.0])
r_vals=np.array([0.0, 1.0])
d_mean = np.zeros((4,))
d_vars = np.ones((4,))
behavior = {'type':'difference', \
            'diff_inds': diff_inds, \
            'c_vals':c_vals, \
            's_vals':s_vals, \
            'r_vals':r_vals, \
            'd_mean':d_mean, \
            'd_var':d_vars}

# set model options
model_opts = {'g_FF':'c', 'g_LAT':'linear', 'g_RUN':'r'}

T = 20
dt = 0.25

T_gt = 1000
dt_gt = 0.01

# %%
r_t_list = [];
r_t_gt_list = [];

num_r0s = 2;
for i in range(num_r0s):
    print(i)
    r0_samp = np.abs(np.random.normal(0,1,(4,)));
    init_conds=np.expand_dims(r0_samp, 1)
    system = V1Circuit(fixed_params, behavior, model_opts, T, dt, init_conds)
    system_gt = V1Circuit(fixed_params, behavior, model_opts, T_gt, dt_gt, init_conds)

    z = tf.placeholder(dtype=tf.float64, shape=(1, None, system.D));
    r_t = system.simulate(z)
    r_t_gt = system_gt.simulate(z)

    _z = np.expand_dims(np.expand_dims(np.arange(0, 1.01, .2), 0), 2)
    num_inputs = _z.shape[1]
    _z = np.tile(_z, [1, 1, 8]);

    with tf.Session() as sess:
        _r_t = sess.run(r_t, {z:_z})
        print('first done')
        _r_t_gt = sess.run(r_t_gt, {z:_z})
        print('second done')
        
    r_t_list.append(_r_t)
    r_t_gt_list.append(_r_t_gt)
# Out:
# 0
# first done
# second done
# 1
# first done
# second done

# %%
num_ntypes = 4
c = 0;
axlim = 2.0;
cm = plt.cm.get_cmap('coolwarm');
fig, axs = plt.subplots(num_ntypes-1, num_ntypes-1, figsize=(12,12))
labels = [r'$r_E$', r'$r_P$', r'$r_S$', r'$r_V$']
fontsize = 20
for ii in range(2):
    _r_t_gt = r_t_gt_list[ii]
    for i in range(num_ntypes-1):
        for j in range(1,num_ntypes):
            ax = axs[i][j-1]
            if (j > i):
                for k in range(num_inputs):
                    ax.plot(_r_t_gt[:,c,k,j], _r_t_gt[:,c,k,i], c=cm(_z[0,k,0]), lw=1, zorder=1)
                    if (k==0):
                        ax.scatter(_r_t_gt[0,c,0,j], _r_t_gt[0,c,0,i], c='g', zorder=2)
                    ax.scatter(_r_t_gt[-1,c,k,j], _r_t_gt[-1,c,k,i], s=40, c='r', zorder=2)
                ax.set_xlim([-.1, axlim])
                ax.set_ylim([-.1, axlim])
            else:
                ax.axis('off')
                
            if (j==i+1):
                ax.set_xlabel(labels[j], fontsize=fontsize)
                ax.set_ylabel(labels[i], fontsize=fontsize)
            
            
plt.show()

# %%
T = 40
dt = 0.25

T_gt = 1000
dt_gt = 0.01

r0_samp = np.abs(np.random.normal(0,1,(4,)))
init_conds=np.expand_dims(r0_samp, 1)
system = V1Circuit(fixed_params, behavior, model_opts, T, dt, init_conds)
system_gt = V1Circuit(fixed_params, behavior, model_opts, T_gt, dt_gt, init_conds)

z = tf.placeholder(dtype=tf.float64, shape=(1, None, system.D));
r_t = system.simulate(z)
r_t_gt = system_gt.simulate(z)

_z = np.expand_dims(np.expand_dims(np.arange(0, 1.01, .2), 0), 2)
num_inputs = _z.shape[1]
_z = np.tile(_z, [1, 1, 8]);

with tf.Session() as sess:
    _r_t = sess.run(r_t, {z:_z})
    _r_t_gt = sess.run(r_t_gt, {z:_z})
    
t = np.arange(0, dt*T, dt)
t_gt = np.arange(0, dt_gt*T_gt, dt_gt)

plt.figure(figsize=(6,12))
for k in range(num_inputs):
    plt.subplot(num_inputs,1, k+1);
    plt.plot(t, _r_t[:,c,k,0], c='k')
    plt.plot(t, _r_t[:,c,k,1], c='b')
    plt.plot(t, _r_t[:,c,k,2], c='r')
    plt.plot(t, _r_t[:,c,k,3], c='g')

    plt.plot(t_gt, _r_t_gt[:,c,k,0], 'k--')
    plt.plot(t_gt, _r_t_gt[:,c,k,1], 'b--')
    plt.plot(t_gt, _r_t_gt[:,c,k,2], 'r--')
    plt.plot(t_gt, _r_t_gt[:,c,k,3], 'g--')

    
    plt.ylabel(r'$r_\alpha(t)$', fontsize=fontsize)
    plt.xlabel('t (s)', fontsize=fontsize-2)
    plt.text(3, .7*np.max(_r_t_gt[:,c,k,3]), 'h = %.1f*[1,1,1,1]' % _z[0,k,0], fontsize=fontsize)

plt.legend(labels)
plt.show()

# %%
T_x = system.compute_suff_stats(z)
print(T_x.shape)
# Out:
# (1, ?, 8)

# %%
bound = 1.0;
start = 0.0;
stop = bound;
res = 0.5;
eps = .001*res;
vals = np.arange(start, stop+eps, res);
num_pts = vals.shape[0];

total_pts = num_pts**8;
params = np.zeros((total_pts,8));
ind = 0;
for i in range(num_pts):
    b_E = vals[i];
    for j in range(num_pts):
        b_P = vals[j];
        for k in range(num_pts):
            b_S = vals[k];
            for l in range(num_pts):
                b_V = vals[l];
                for ii in range(num_pts):
                    h_RUNE = vals[ii];
                    for jj in range(num_pts):
                        h_RUNP = vals[jj];
                        for kk in range(num_pts):
                            h_RUNS = vals[kk];
                            for ll in range(num_pts):
                                h_RUNV = vals[ll];
                                params[ind,:] = np.array([b_E, b_P, b_S, b_V, \
                                                          h_RUNE, h_RUNP, h_RUNS, h_RUNV]);
                                ind += 1;

# %%
_z = np.expand_dims(params, 0)
with tf.Session() as sess:
    _T_x = sess.run(T_x, {z:_z})

# %%
figsize = (12,12);
fontsize = 12;
plt.figure(figsize=figsize);

bound = 2;
fontsize = 25;
figsize = (14, 14);
plt.figure(figsize=figsize);
for i in range(system.num_suff_stats):
    plt.subplot(1, system.num_suff_stats, i+1);
    for j in range(system.num_suff_stats):
        ind = system.num_suff_stats*i + j + 1;
        plt.subplot(system.num_suff_stats, system.num_suff_stats, ind);
        plt.scatter(_T_x[0,:,j], _T_x[0, :, i], s=1);
        if (i==(system.D-1)):
            plt.xlabel(system.T_x_labels[j], fontsize=fontsize);
        if (j==0):
            plt.ylabel(system.T_x_labels[i], fontsize=fontsize);
        #plt.xlim([-bound, bound]);
        #plt.ylim([-bound, bound]);
    print(np.mean(_T_x[0,:,i]),0);

plt.show();
# Out:
# 0.021316968893533267 0
# 0.128715753888381 0
# 1.0623806443137198 0
# 0.2514974707567356 0
# 0.17341806175284255 0
# 0.09464052151198112 0
# 2.1483869765591295 0
# 2.117372756535291 0
