# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tf_util.systems import system_from_str
from train_dsn import train_dsn
import seaborn as sns
import pandas as pd

from util import fct_integrals as integrals
from util import tf_integrals as tf_integrals

from util import fct_mf as mf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TIF_flow_type = 'AffineFlowLayer';
nlayers = 1;
flow_dict = {'latent_dynamics':None, \
             'TIF_flow_type':TIF_flow_type, \
             'repeats':nlayers};

n = 1000;
k_max = 1;
c_init = 1e0;
check_rate = 1;
max_iters = 10000;
lr_order = -3;
random_seed = 0;

def compute_bistable_mu(Sini, ics_0, ics_1):
    ### Set parameters

    Mm = 3.5      # Mean of m
    Mn = 1.       # Mean of n
    Mi = 0.       # Mean of I

    Sim = 1.      # Std of m
    Sin = 1.      # Std of n
    Sip = 1.      # Std of input orthogonal to m and n, along h (see Methods)

    g = 0.8
    tol = 1e-10;
    
    eps = 0.2;
    
    ParVec = [Mm, Mn, Mi, Sim, Sin, Sini, Sip];
    ys0, count = mf.SolveStatic(ics_0, g, ParVec, eps, tol);
    ys1, count = mf.SolveStatic(ics_1, g, ParVec, eps, tol);
    
    ss0 = ys0[-1,2];
    ss1 = ys1[-1,2];
    mu = np.array([ss0, ss1]);
    return mu;

# %%
system_str = 'rank1_rnn';

K = 1;
M = n;
behavior_str = 'bistable';
D = 20;
T = 15;
Sini = 0.5;
ics_0 = np.array([5., 5., 5.], np.float64);
ics_1 = np.array([-5., 5., -5.], np.float64);

Ics_0 = np.tile(np.expand_dims(np.expand_dims(ics_0, 0), 1), [K,M,1]);
Ics_1 = np.tile(np.expand_dims(np.expand_dims(ics_1, 0), 1), [K,M,1]);

system_class = system_from_str(system_str);
system = system_class(D, T, Sini, Ics_0, Ics_1, behavior_str);

mu = compute_bistable_mu(Sini, ics_0, ics_1);
Sigma = 0.01*np.ones((2,));
behavior = {'mu':mu, 'Sigma':Sigma};



cost, phi, T_x = train_dsn(system, behavior, n, flow_dict, \
                       k_max=k_max, c_init=c_init, lr_order=lr_order, check_rate=check_rate, \
                       max_iters=max_iters, random_seed=random_seed);
# Out:
# c_init 1.0
# results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/
# 0 <tf_util.flows.AffineFlowLayer object at 0x134dca550>
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x134dca908>
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x134dcac50>
# zshapes in
# connect flow
# (?, ?, 20, ?)
# 0 AffineFlow_Layer1
# (?, ?, 20, ?)
# (3, ?, 1000)
# (3, ?, 1000)
# (?, 1000, 2, 3)
# training DSN for rank1_rnn: dt=0.001, T=15
# AL iteration 1
# resetting optimizer
# aug lag it 0
# saving model at iter 0
# ******************************************
# it = 2
# H 18.010675714871578
# cost -16.24392029821312
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 3
# H 18.478431014007306
# cost -16.74109200339578
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 4
# H 18.640230253646234
# cost -16.928763519040828
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 5
# H 19.123742739914086
# cost -17.431152987793716
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 6
# H 19.26079141106476
# cost -17.584523803785697
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 7
# H 19.402010015467486
# cost -17.739814902865398
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 8
# H 19.655209593248
# cost -18.004707680987554
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 9
# H 19.86477418323529
# cost -18.224380598411464
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 10
# H 20.016808967568156
# cost -18.385384351578125
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 11
# H 20.10984815922848
# cost -18.487024498985157
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it =
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 477
# H 29.209141179096804
# cost -28.101038741452385
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 478
# H 29.11511078791613
# cost -28.000841738418526
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 479
# H 29.126197835083286
# cost -28.023344217220576
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 480
# H 29.172990141204217
# cost -28.0555352113733
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 481
# H 29.147277622047266
# cost -28.021296850448906
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 482
# H 29.048784390876598
# cost -27.938834978379035
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 483
# H 29.209913514398753
# cost -28.10756022651752
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 484
# H 29.035103695141
# cost -27.922362165539933
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 485
# H 28.901169569551033
# cost -27.793484305514237
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 486
# H 29.219464517794858
# cost -28.108576431725
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 487
# H 28.98747315592256
# cost -27.86924896670077
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 488
# H 29.141457890011758
# cost -28.033317155641864
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 489
# H 29.031216239879765
# cost -27.918962304402147
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 490
# H 29.143218847310795
# cost -28.030925237191482
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 491
# H 28.943026219001226
# cost -27.82914151811923
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 492
# H 29.217749065635278
# cost -28.09834606250445
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 493
# H 28.94860360060255
# cost -27.839603886379688
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 494
# H 28.85605569149928
# cost -27.736067508998584
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 495
# H 29.082776683496707
# cost -27.979213257016287
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 496
# H 29.123011064104716
# cost -28.010712313508403
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 497
# H 29.1653135981086
# cost -28.05877554711385
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 498
# H 29.13960360916892
# cost -28.022116016348654
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 499
# H 29.19795090113466
# cost -28.086757094915598
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 500
# H 29.254169446795405
# cost -28.13949710549067
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 501
# H 29.30772523073161
# cost -28.19907927993174
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 502
# H 29.120834666348383
# cost -28.016696550486497
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 503
# H 29.416568174219393
# cost -28.30005698489685
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 504
# H 29.333282124490577
# cost -28.23075217800284
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 505
# H 29.28536252404937
# cost -28.176017354034872
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 506
# H 29.084297408974034
# cost -27.975632220180614
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 507
# H 29.252061341683095
# cost -28.14148194578783
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 508
# H 29.159816868020442
# cost -28.041701276451573
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 509
# H 29.33704475641329
# cost -28.216272174442476
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 510
# H 29.330011260850707
# cost -28.215886514761696
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 511
# H 29.300319066379988
# cost -28.18491146024956
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 512
# H 29.118121871487222
# cost -28.014744301458208
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 513
# H 29.129474699084405
# cost -28.010525264631656
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 514
# H 29.288180965571964
# cost -28.16240023196032
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ******************************************
# it = 515
# H 29.33020268822455
# cost -28.229548273996528
# saving to results//tb/rank1_rnn_D=20_T=15_flow=1A_lr_order=-3_c=0_rs=0/  ...
# ******************************************
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-11-bbfe1718a993>", line 24, in <module>
#     cost, phi, T_x = train_dsn(system, behavior, n, flow_dict,                        k_max=k_max, c_init=c_init, lr_order=lr_order, check_rate=check_rate,                        max_iters=max_iters, random_seed=random_seed);
#   File "/Users/sbittner/Documents/dsn/train_dsn.py", line 230, in train_dsn
#     _H, _T_x, _phi, _log_q_x = sess.run([H, T_x, phi, log_q_x], feed_dict);
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 900, in run
#     run_metadata_ptr)
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 1135, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 1316, in _do_run
#     run_metadata)
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 1322, in _do_call
#     return fn(*args)
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 1307, in _run_fn
#     options, feed_dict, fetch_list, target_list, run_metadata)
#   File "/Users/sbittner/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py", line 1409, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1806, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py", line 1453, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py", line 1411, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py", line 666, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py", line 712, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/posixpath.py", line 386, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/posixpath.py", line 420, in _joinrealpath
#     if not islink(newpath):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/posixpath.py", line 169, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
