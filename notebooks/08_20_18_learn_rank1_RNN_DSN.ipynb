# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tf_util.systems import system_from_str
from train_dsn import train_dsn
import seaborn as sns
import pandas as pd

from util import fct_integrals as integrals
from util import tf_integrals as tf_integrals

from util import fct_mf as mf

# %%
TIF_flow_type = 'PlanarFlowLayer';
nlayers = 10;
flow_dict = {'latent_dynamics':None, \
             'TIF_flow_type':TIF_flow_type, \
             'repeats':nlayers};

n = 1000;
k_max = 1;
c_init = 1e4;
check_rate = 100;
max_iters = 10000;
lr_order = -3;
random_seed = 0;

def compute_bistable_mu(Sini, ics_0, ics_1):
    ### Set parameters

    Mm = 3.5      # Mean of m
    Mn = 1.       # Mean of n
    Mi = 0.       # Mean of I

    Sim = 1.      # Std of m
    Sin = 1.      # Std of n
    Sip = 1.      # Std of input orthogonal to m and n, along h (see Methods)

    g = 0.8
    tol = 1e-10;
    
    eps = 0.2;
    
    ParVec = [Mm, Mn, Mi, Sim, Sin, Sini, Sip];
    ys0, count = mf.SolveStatic(ics_0, g, ParVec, eps, tol);
    ys1, count = mf.SolveStatic(ics_1, g, ParVec, eps, tol);
    
    ss0 = ys0[-1,2];
    ss1 = ys1[-1,2];
    mu = np.array([ss0, ss1]);
    return mu;

# %%
system_str = 'rank1_rnn';

K = 1;
M = n;
behavior_str = 'bistable';
D = 10;
T = 10;
Sini = 0.5;
ics_0 = np.array([5., 5., 5.], np.float64);
ics_1 = np.array([-5., 5., -5.], np.float64);

Ics_0 = np.tile(np.expand_dims(np.expand_dims(ics_0, 0), 1), [K,M,1]);
Ics_1 = np.tile(np.expand_dims(np.expand_dims(ics_1, 0), 1), [K,M,1]);

system_class = system_from_str(system_str);
system = system_class(D, T, Sini, Ics_0, Ics_1, behavior_str);

mu = compute_bistable_mu(Sini, ics_0, ics_1);
Sigma = 0.01*np.ones((2,));
behavior = {'mu':mu, 'Sigma':Sigma};



cost, phi, T_x = train_dsn(system, behavior, n, flow_dict, \
                       k_max=k_max, c_init=c_init, lr_order=lr_order, check_rate=check_rate, \
                       max_iters=max_iters, random_seed=random_seed);
# Out:
# c_init 10000.0
# results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/
# 0 <tf_util.flows.PlanarFlowLayer object at 0x1317fb198>
# 1 <tf_util.flows.PlanarFlowLayer object at 0x1317fb160>
# 2 <tf_util.flows.PlanarFlowLayer object at 0x1317fb240>
# 3 <tf_util.flows.PlanarFlowLayer object at 0x1317fb1d0>
# 4 <tf_util.flows.PlanarFlowLayer object at 0x1317fb400>
# 5 <tf_util.flows.PlanarFlowLayer object at 0x1317fb438>
# 6 <tf_util.flows.PlanarFlowLayer object at 0x1317fb470>
# 7 <tf_util.flows.PlanarFlowLayer object at 0x1317fb4a8>
# 8 <tf_util.flows.PlanarFlowLayer object at 0x1317fb4e0>
# 9 <tf_util.flows.PlanarFlowLayer object at 0x1317fb518>
# Tensor("Const_20:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1317fb3c8>
# Tensor("Const_21:0", shape=(1, 1), dtype=float64)
# Tensor("Const_22:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x131837a20>
# Tensor("Const_23:0", shape=(1, 1), dtype=float64)
# Tensor("Const_24:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x13184ea90>
# Tensor("Const_25:0", shape=(1, 1), dtype=float64)
# Tensor("Const_26:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x13186b5f8>
# Tensor("Const_27:0", shape=(1, 1), dtype=float64)
# Tensor("Const_28:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1318827f0>
# Tensor("Const_29:0", shape=(1, 1), dtype=float64)
# Tensor("Const_30:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x131882ac8>
# Tensor("Const_31:0", shape=(1, 1), dtype=float64)
# Tensor("Const_32:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1318c17f0>
# Tensor("Const_33:0", shape=(1, 1), dtype=float64)
# Tensor("Const_34:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1318a07f0>
# Tensor("Const_35:0", shape=(1, 1), dtype=float64)
# Tensor("Const_36:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1318deb70>
# Tensor("Const_37:0", shape=(1, 1), dtype=float64)
# Tensor("Const_38:0", shape=(10, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x13191df98>
# Tensor("Const_39:0", shape=(1, 1), dtype=float64)
# zshapes in
# connect flow
# (?, ?, 10, ?)
# 0 PlanarFlow_Layer1
# (?, ?, 10, ?)
# 1 PlanarFlow_Layer2
# (?, ?, 10, ?)
# 2 PlanarFlow_Layer3
# (?, ?, 10, ?)
# 3 PlanarFlow_Layer4
# (?, ?, 10, ?)
# 4 PlanarFlow_Layer5
# (?, ?, 10, ?)
# 5 PlanarFlow_Layer6
# (?, ?, 10, ?)
# 6 PlanarFlow_Layer7
# (?, ?, 10, ?)
# 7 PlanarFlow_Layer8
# (?, ?, 10, ?)
# 8 PlanarFlow_Layer9
# (?, ?, 10, ?)
# 9 PlanarFlow_Layer10
# (?, ?, 10, ?)
# training DSN for rank1_rnn: dt=0.001, T=10
# AL iteration 1
# resetting optimizer
# aug lag it 0
# lambda [0. 0. 0. 0.]
# c 10000.0
# saving model at iter 0
# ******************************************
# it = 100
# H 12.343750734512039
# cost 14246.560880896592
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 200
# H 13.132040160753492
# cost 11543.552096280691
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 300
# H 12.781179413923146
# cost 11229.948230675669
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 400
# H 12.680637848536044
# cost 11197.983423194793
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 500
# H 12.57180541456377
# cost 11043.681893773663
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 600
# H 12.648687885489599
# cost 10945.212182464527
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 700
# H 12.622854875342604
# cost 10815.695843534519
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 800
# H 12.65706287099053
# cost 10768.985922235797
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 900
# H 12.468045401478117
# cost 10718.949171088112
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1000
# H 12.531916469595053
# cost 10822.000365536369
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1100
# H 12.530330898936487
# cost 10616.96462735345
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1200
# H 12.427704269396346
# cost 10733.340133646123
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 1300
# H 12.575007394401297
# cost 10550.410209402253
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1400
# H 12.510383689362575
# cost 10547.217365097275
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1500
# H 12.488846857134195
# cost 10463.297864949174
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1600
# H 12.56110830841599
# cost 10611.473592173636
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1700
# H 12.4250542259693
# cost 10490.915809709228
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1800
# H 12.47270309957149
# cost 10535.020352273677
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 1900
# H 12.442568199948997
# cost 10542.745204937823
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2000
# H 12.461299921784098
# cost 10431.829468198635
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2100
# H 12.392187035224664
# cost 10358.941471272781
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2200
# H 12.505955799680473
# cost 10338.596928692748
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2300
# H 12.566462454927864
# cost 10364.128544719275
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2400
# H 12.409023513025963
# cost 10273.569863272429
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2500
# H 12.384774682770576
# cost 10496.46488463675
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# Doubling memory allocation for parameter logging.
# ******************************************
# it = 2600
# H 12.402271346193942
# cost 10337.435059614203
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2700
# H 12.44940602119576
# cost 10406.097514820854
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2800
# H 12.439895815599058
# cost 10265.274238734723
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 2900
# H 12.590625046468318
# cost 10364.369226350807
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3000
# H 12.52095521731354
# cost 10289.99400830594
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3100
# H 12.54727739748317
# cost 10248.999821145333
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3200
# H 12.671557906884336
# cost 10164.73531207681
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3300
# H 12.571647161992754
# cost 10264.420821431228
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3400
# H 12.60574720481395
# cost 10398.070687203131
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3500
# H 12.377598406977402
# cost 10578.642197411053
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3600
# H 12.453370902966075
# cost 10107.844105117736
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3700
# H 12.51664476266539
# cost 10384.33439945194
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3800
# H 12.637595653530363
# cost 10515.958742020064
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 3900
# H 12.723267972954835
# cost 10193.223079533396
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 4000
# H 12.562469277720039
# cost 10096.675144526129
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 4100
# H 12.478492618651849
# cost 10103.6413566075
# rank1 RNN!
# saving to results//tb/rank1_rnn_D=10_T=10_flow=10P_lr_order=-3_c=4_rs=0/  ...
# ******************************************
# ******************************************
# it = 